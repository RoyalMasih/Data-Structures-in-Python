# %%
#23. Write a code to concatenate two tubles. The function should take two tuples as input and return a new tuple containing elements from both input tuples.
str1= input(("Enter a tuple:"))
tuple1 = tuple(str1.split(","))
str2= input(("Enter a tuple:"))
tuple2 = tuple(str2.split(","))
result = tuple1+tuple2
print(result)
# Out:
# Enter a tuple:1,2,3
# Enter a tuple:15
# ('1', '2', '3', '15')

# %%
type(tuple1)
# Out:
# tuple
