# %%
#30. Develop a code that prompts the user to input two sets of strings. Then, print  the symmetric difference of these two sets.
str1 = set(input("Kindly enter a set of strings:").split())
str2 = set(input("Kindly enter a set of strings:").split())
sym_dif = str1.symmetric_difference(str2)
print(sym_dif)
# Out:
# Kindly enter a set of strings:my name is royal
# Kindly enter a set of strings:i am a student of pwskills
# {'student', 'pwskills', 'i', 'my', 'of', 'is', 'royal', 'a', 'name', 'am'}
