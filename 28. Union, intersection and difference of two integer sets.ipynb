# %%
#28. Create a code that define two sets of integers. Then, print the union, intersection, and difference of these two sets.
set1 = set([1,2,3,4,5,6])
set2 = set([4,5,6,7,8,9])
set_union = set1.union(set2)
print("Sets Union is :", set_union)
set_intersection = set1.intersection(set2)
print("Sets intersection is :", set_intersection)
set_dif = set1^set2
print("Sets difference is :", set_dif)
# Out:
# Sets Union is : {1, 2, 3, 4, 5, 6, 7, 8, 9}
# Sets intersection is : {4, 5, 6}
# Sets difference is : {1, 2, 3, 7, 8, 9}
